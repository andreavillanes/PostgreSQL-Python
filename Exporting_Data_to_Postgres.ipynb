# %%
import glob
import pandas as pd
import os as os
from sqlalchemy import create_engine
import psycopg2 
import io

df = pd.read_csv("C:/Users/avillan/Documents/Class 2026/SQL - Fall/PostgreSQL/Communicable_Lexicon.csv")

#following this structure:  engine = create _engine('postgresql+psycopg2://user:password@hostname/database_name')
engine = create_engine('postgresql+psycopg2://postgres:class@localhost:5432/postgres')

df.to_sql('Lexicon', engine, schema="Practicum_test")
